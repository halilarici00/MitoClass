# %%
import matplotlib.pyplot as plt

def plot_precision_recall_curve(precision, recall):
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, marker='o', linestyle='-')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.grid(True)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.tight_layout()
    plt.show()

# Precision and recall values, we had to manually enter each value here and calculate the curve here.
# Making this code run in the original code was a headache and it was not working. Thus, we had to print the values in that code.
# Manually write them here and plot the curve here.
precision_values_resnet50 = [0.6775,0.6938,0.7129,0.7294,0.7450,0.7612,0.7730,0.7858,0.7970,0.8099,0.8251,0.8379,0.8488,0.8574,0.8681,0.8757,0.8865,0.8939,0.9051,0.9127,0.9182,0.9326,0.9349,0.9419,0.9493,0.9552,0.9585,0.9655,0.9692,0.9705,0.9704,0.9759,0.9761,0.9791,0.9833,0.9913,0.9939,0.9890,0.9804,0.96,0.9091,0.8333,0.9999,0.9999,0]
recall_values_resnet50 = [0.8681,0.8631,0.8562,0.8502,0.8403,0.8318,0.8194,0.8115,0.8041,0.7902,0.7768,0.7639,0.7490,0.7307,0.7148,0.6989,0.6820,0.6646,0.6434,0.6225,0.5957,0.5694,0.5417,0.5144,0.4826,0.4544,0.4241,0.3884,0.3591,0.3259,0.2932,0.2614,0.2227,0.1860,0.1458,0.1126,0.0809,0.0447,0.0248,0.0119,0.005,0.0025,0.0015,0.0005,0]

precision_values_resnet34=[0.7444,0.7608,0.7811,0.7937,0.8061,0.8221,0.8383,0.8523,0.8655,0.8731,0.8849,0.8954,0.9092,0.9166,0.9288,0.9289,0.9325,0.937,0.9448,0.9509,0.9532,0.958,0.9624,0.9647,0.963,0.9714,0.9689,0.9729,0.9744,0.9769,0.983,0.9776,0.9677,0.9706,1,1,1,1,1]
recall_values_resnet34=[0.7674,0.754,0.7416,0.7292,0.7113,0.6969,0.6791,0.6582,0.6414,0.6280,0.6062,0.5863,0.5709,0.5505,0.5302,0.5055,0.4797,0.4499,0.4157,0.3839,0.3537,0.3279,0.3046,0.2713,0.2451,0.2187,0.1855,0.1602,0.1324,0.1047,0.0858,0.065,0.0446,0.0327,0.0198,0.0139,0.0064,0.003,0.0005]

#last is for resnet18
precision_values=[0.6477,0.6683,0.6857,0.7033,0.7191,0.7350,0.7499,0.7665,0.78,0.7888,0.8031,0.8097,0.8274,0.8434,0.8560,0.8633,0.8734,0.8828,0.8953,0.9111,0.9172,0.9279,0.9311,0.9384,0.9473,0.9518,0.9615,0.9609,0.9637,0.9648,0.9697,0.9725,0.9713,0.9691,0.9736,0.9643,0.9618,0.9663,0.963,0.9655,0.9444,0.9166,0.6667,1,1,0]
recall_values=[0.8254,0.8165,0.8095,0.8006,0.7887,0.7788,0.7659,0.7525,0.7351,0.7207,0.6999,0.6840,0.6682,0.6518,0.6344,0.6141,0.5918,0.568,0.5387,0.5233,0.4999,0.4722,0.4425,0.4157,0.3924,0.3621,0.3343,0.3051,0.2763,0.2450,0.2222,0.1929,0.1682,0.1399,0.1096,0.0804,0.0625,0.0427,0.0258,0.0139,0.0084,0.0055,0.0009,0.0005,0.0005,0]
plot_precision_recall_curve(precision_values, recall_values)
